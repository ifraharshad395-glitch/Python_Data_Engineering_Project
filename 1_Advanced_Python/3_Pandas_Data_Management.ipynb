# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup 
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample()
# Out:
#        job_title_short                                  job_title  \
# 128312    Data Analyst  Financial Data Analyst (H/F) - Alternance
#
#          job_location       job_via job_schedule_type  job_work_from_home  \
# 128312  Paris, France  via LinkedIn         Full-time               False
#
#        search_location     job_posted_date  job_no_degree_mention  \
# 128312          France 2023-08-25 08:18:57                  False
#
#         job_health_insurance job_country salary_rate  salary_year_avg  \
# 128312                 False      France         NaN              NaN
#
#         salary_hour_avg             company_name  \
# 128312              NaN  Publicis Sapient France
#
#                           job_skills  \
# 128312  ['vba', 'power bi', 'excel']
#
#                                           job_type_skills
# 128312  {'analyst_tools': ['power bi', 'excel'], 'prog...

# %%
df.sample(10)
# Out:
#               job_title_short  \
# 722203           Data Analyst
# 622738         Cloud Engineer
# 721552          Data Engineer
# 99072            Data Analyst
# 326814  Senior Data Scientist
# 750973  Senior Data Scientist
# 551134         Data Scientist
# 269977          Data Engineer
# 439750           Data Analyst
# 633305         Data Scientist
#
#                                                 job_title        job_location  \
# 722203  Data Analyst Tableau Developer - Insurance/Rei...        Stamford, CT
# 622738                      Senior Cloud Support Engineer      Warsaw, Poland
# 721552                         DATA ENGINEER: INFORMATICA       United States
# 99072                          Data analyst and Developer             Georgia
# 326814  Think Big Analytics Sr Data Scientist /シニアデータサ...        Tokyo, Japan
# 750973              (Senior) Manager Data Science (w/m/d)  Frankfurt, Germany
# 551134  Sr. Solution Engineer (Data Scientist) German ...            Anywhere
# 269977                                      Data Engineer       Madrid, Spain
# 439750  2023 Launch Program: Associate Data Analyst In...       Charlotte, NC
# 633305                                 Sr. Data Scientist          Boston, MA
#
#                       job_via job_schedule_type  job_work_from_home  \
# 722203           via LinkedIn         Full-time               False
# 622738  via Praca Trabajo.org         Full-time               False
# 721552        via SimplyHired         Full-time               False
# 99072              via Indeed         Full-time               False
# 326814         via エリートネットワーク         Full-time               False
# 750973               via XING         Full-time               False
# 551134             via Indeed         Full-time                True
# 269977              via BeBee         Full-time               False
# 439750         via Startupers         Full-time               False
# 633305           via LinkedIn         Full-time               False
#
#                 search_location     job_posted_date  job_no_degree_mention  \
# 722203  New York, United States 2023-08-31 21:00:20                  False
# 622738                   Poland 2023-08-30 12:32:06                  False
# 721552                  Georgia 2023-01-31 22:33:55                  False
# 99072                   Georgia 2023-11-29 00:41:15                  False
# 326814                    Japan 2023-01-20 00:03:25                  False
# 750973                  Germany 2023-10-06 20:12:38                  False
# 551134                  Austria 2023-06-16 20:08:05                  False
# 269977                    Spain 2023-04-28 07:17:12                   True
# 439750                  Georgia 2023-02-09 17:26:20                  False
# 633305  New York, United States 2023-06-27 12:03:51                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 722203                 False  United States         NaN              NaN
# 622738                 False         Poland         NaN              NaN
# 721552                 False  United States         NaN              NaN
# 99072                  False  United States         NaN              NaN
# 326814                 False          Japan         NaN              NaN
# 750973                 False        Germany         NaN              NaN
# 551134                 False        Austria         NaN              NaN
# 269977                 False          Spain         NaN              NaN
# 439750                  True  United States         NaN              NaN
# 633305                 False  United States         NaN              NaN
#
#         salary_hour_avg                            company_name  \
# 722203              NaN                               OdysseyRe
# 622738              NaN                               Snowflake
# 721552              NaN                                UniGroup
# 99072               NaN                         Bentley Systems
# 326814              NaN                             データウェアハウス企業
# 750973              NaN  BDO AG Wirtschaftsprüfungsgesellschaft
# 551134              NaN                             DeepOpinion
# 269977              NaN       Nommon Solutions and Technologies
# 439750              NaN                            Red Ventures
# 633305              NaN                 Plymouth Rock Assurance
#
#                                                job_skills  \
# 722203                        ['sql', 'tableau', 'excel']
# 622738  ['sql', 'python', 'java', 'r', 'snowflake', 'a...
# 721552  ['sql', 'python', 'snowflake', 'aws', 'kafka',...
# 99072                        ['sql', 'snowflake', 'qlik']
# 326814          ['r', 'python', 'sql', 'nosql', 'hadoop']
# 750973   ['python', 'r', 'java', 'tensorflow', 'pytorch']
# 551134  ['python', 'bash', 'numpy', 'scikit-learn', 'm...
# 269977  ['python', 'mongo', 'java', 'no-sql', 'aws', '...
# 439750   ['python', 'sql', 'spring', 'pandas', 'tableau']
# 633305                      ['python', 'r', 'sas', 'sas']
#
#                                           job_type_skills
# 722203  {'analyst_tools': ['tableau', 'excel'], 'progr...
# 622738  {'cloud': ['snowflake', 'aws', 'azure', 'gcp']...
# 721552  {'cloud': ['snowflake', 'aws'], 'libraries': [...
# 99072   {'analyst_tools': ['qlik'], 'cloud': ['snowfla...
# 326814  {'libraries': ['hadoop'], 'programming': ['r',...
# 750973  {'libraries': ['tensorflow', 'pytorch'], 'prog...
# 551134  {'libraries': ['numpy', 'scikit-learn', 'matpl...
# 269977  {'analyst_tools': ['tableau', 'qlik', 'power b...
# 439750  {'analyst_tools': ['tableau'], 'libraries': ['...
# 633305  {'analyst_tools': ['sas'], 'programming': ['py...

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

df_altered = df_original.copy()


print('ID of df_original: ', id(df_original))
print('ID of df_altered: ', id(df_altered))
print('Are the two dataframes same? ', id(df_original)==id(df_altered))
# Out:
# ID of df_original:  2787714503952
# ID of df_altered:  2787552825296
# Are the two dataframes same?  False

# %%
median_salary = df_altered['salary_year_avg'].median()
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5, 'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64
